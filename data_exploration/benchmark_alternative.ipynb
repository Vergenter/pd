# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,1,2,3])
y = np.array([20,21,22,23])
my_xticks = ['John','Arnold','Mavis','Matt']
plt.xticks(x, my_xticks)
plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
y = [13485,36950,95867,246468,746051,1101792,1166243]
z = [1666, 4980, 12974, 31971, 69499,120740,169343]
n = [58, 100, 200, 300, 400,500,600]
year = [2003,2007,2010,2013,2016,2018,2020]
fig, ax = plt.subplots(figsize=(6, 6))
for _y,_z,_n,_year in zip(y,z,n,year):
    ax.scatter(_y,_z,label=_year)
    ax.annotate(_n, ( _y,_z))
fig.legend(loc="right",shadow=True, fancybox=True)
plt.xlabel("edges")
plt.ylabel("nodes")
ax.ticklabel_format(style='plain')
plt.title("Time for method_x from nodes and edges", fontsize=16)
plt.tight_layout()

# %%
nodes = [1666, 4980, 12974, 31971, 69499,120740,169343]
edges = [13485,36950,95867,246468,746051,1101792,1166243]
nodes_and_edges = list(zip(nodes,edges))
x = range(len(nodes_and_edges))
year = ["<=2003","<=2007","<=2010","<=2013","<=2016","<=2018","<=2020"]
y = [58, 100, 200, 300, 400,500,600]
my_xticks = [str(x) for x in nodes_and_edges]
fig, ax = plt.subplots(figsize=(10, 6))
plt.xticks(x, my_xticks)
for _x,_y,_year in zip(x,y,year):
    ax.scatter(_x,_y,label=_year)
    # ax.annotate(_n, ( _y,_z))
# fig.legend(reversed(fig.legend().legendHandles),loc="right",shadow=True, fancybox=True)

plt.legend(reversed(plt.legend().legendHandles), reversed(year))
plt.xlabel("(nodes,edges)")
plt.ylabel("time")
plt.title("Time for method_x from nodes and edges", fontsize=16)
plt.tight_layout()
plt.show()

# %%
nodes = [1666, 4980, 12974, 31971, 69499,120740,169343]
edges = [13485,36950,95867,246468,746051,1101792,1166243]
nodes_and_edges = list(zip(nodes,edges))
x = range(len(nodes_and_edges))
year = ["<=2003","<=2007","<=2010","<=2013","<=2016","<=2018","<=2020"]
y = [58, 100, 200, 300, 400,500,600]
my_xticks = [str(x) for x in nodes_and_edges]
fig, ax = plt.subplots(figsize=(10, 6))
plt.xticks(x, my_xticks)
for _x,_y,_year in zip(x,y,year):
    ax.scatter(_x,_y,label=_year)
    ax.annotate(_year, ( _x,_y))
# fig.legend(reversed(fig.legend().legendHandles), reversed(year))
plt.xlabel("(nodes,edges)")
plt.ylabel("time")
plt.title("Time for method_x from nodes and edges", fontsize=16)
plt.tight_layout()
# plt.plot(x, y)
plt.show()

# %%
y = [13485,36950,95867,246468,746051,1101792,1166243]
